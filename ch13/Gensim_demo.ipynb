# %% [markdown]
# #Gensim Example
#
# pip install gensim

# %%
from gensim import corpora,models,similarities
from sklearn.datasets import fetch_20newsgroups as getData
from sklearn.model_selection import train_test_split
from collections import defaultdict
import re
import numpy as np


corpus = getData(subset='train', 
                             remove=('headers', 'footers', 'quotes'),
                            categories=['alt.atheism','comp.graphics',
                                       'soc.religion.christian'])
X = corpus.data
y = corpus.target
y_names = corpus.target_names

print(X[0],len(X),y_names[y[0]])
# Out:
# I would rather be at a higher risk of being killed than actually killed by
#                               ^^^^                      ^^^^^^^^
# mistake.  Though I do agree with the concept that the type D and E murderers
# are a massive waste of space and resources I don't agree with the concept:
#
# 	killing is wrong
# 	if you kill we will punish you
# 	our punishment will be to kill you.
#
# Seems to be lacking in consistency.
#  1663 alt.atheism

# %%
type(X[0])
# Out:
# str

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.1,shuffle=True)
stoplist = set('for a of the and to in'.split(' '))
texts = [[word for word in re.split('\W+',doc.lower()) if word not in stoplist]
         for doc in Xtrain]

print(len(texts))
# Out:
# 1496

# %% [markdown]
# removed words over used

# %%
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

cutOffValue = 10
processed_corpus = [[token for token in text if frequency[token] > cutOffValue] 
                    for text in texts]

dictionary = corpora.Dictionary(processed_corpus)
print(dictionary)
# Out:
# Dictionary(2798 unique tokens: ['', 'action', 'actions', 'after', 'again']...)

# %%
print(dictionary.token2id)
# Out:
# {'': 0, 'action': 1, 'actions': 2, 'after': 3, 'again': 4, 'allow': 5, 'allowed': 6, 'already': 7, 'although': 8, 'am': 9, 'an': 10, 'anger': 11, 'any': 12, 'as': 13, 'ask': 14, 'at': 15, 'attempt': 16, 'aware': 17, 'be': 18, 'bear': 19, 'been': 20, 'before': 21, 'being': 22, 'beliefs': 23, 'believed': 24, 'bible': 25, 'blood': 26, 'body': 27, 'books': 28, 'born': 29, 'buddhism': 30, 'but': 31, 'by': 32, 'came': 33, 'can': 34, 'catholic': 35, 'celebrate': 36, 'chance': 37, 'choice': 38, 'christ': 39, 'christian': 40, 'christianity': 41, 'church': 42, 'clear': 43, 'commandments': 44, 'communion': 45, 'community': 46, 'continue': 47, 'copy': 48, 'date': 49, 'daughter': 50, 'days': 51, 'decided': 52, 'describe': 53, 'did': 54, 'directly': 55, 'discussed': 56, 'disease': 57, 'divorce': 58, 'do': 59, 'does': 60, 'drive': 61, 'due': 62, 'during': 63, 'e': 64, 'easter': 65, 'effectively': 66, 'enough': 67, 'every': 68, 'ex': 69, 'face': 70, 'faith': 71, 'fall': 72, 'fallen': 73, 'father': 74, 'feel': 75, 'felt': 76, 'five': 77, 'force': 78, 'free': 79, 'from': 80, 'had': 81, 'hand': 82, 'happy': 83, 'has': 84, 'have': 85, 'help': 86, 'her': 87, 'hope': 88, 'i': 89, 'if': 90, 'influence': 91, 'into': 92, 'is': 93, 'it': 94, 'keep': 95, 'last': 96, 'later': 97, 'left': 98, 'm': 99, 'made': 100, 'mail': 101, 'marriage': 102, 'married': 103, 'me': 104, 'member': 105, 'mental': 106, 'months': 107, 'mother': 108, 'my': 109, 'naturally': 110, 'need': 111, 'never': 112, 'newsgroup': 113, 'no': 114, 'non': 115, 'not': 116, 'number': 117, 'often': 118, 'old': 119, 'only': 120, 'or': 121, 'other': 122, 'our': 123, 'out': 124, 'over': 125, 'period': 126, 'please': 127, 'post': 128, 'practice': 129, 'primarily': 130, 'problem': 131, 'quite': 132, 'read': 133, 'reader': 134, 'realize': 135, 'really': 136, 'regular': 137, 'religion': 138, 'religious': 139, 'response': 140, 'rights': 141, 'saturday': 142, 'seeing': 143, 'separation': 144, 'set': 145, 'several': 146, 'she': 147, 'should': 148, 'since': 149, 'situation': 150, 'society': 151, 'some': 152, 'started': 153, 'study': 154, 'suggest': 155, 'suggested': 156, 'suggestions': 157, 'sunday': 158, 't': 159, 'taken': 160, 'taking': 161, 'teachings': 162, 'thanks': 163, 'that': 164, 'then': 165, 'there': 166, 'think': 167, 'this': 168, 'though': 169, 'time': 170, 'today': 171, 'too': 172, 'took': 173, 'tried': 174, 'try': 175, 'two': 176, 'under': 177, 'up': 178, 'upon': 179, 'us': 180, 've': 181, 'want': 182, 'was': 183, 'wasn': 184, 'we': 185, 'were': 186, 'when': 187, 'which': 188, 'while': 189, 'why': 190, 'wife': 191, 'willing': 192, 'with': 193, 'woman': 194, 'words': 195, 'would': 196, 'year': 197, 'years': 198, 'you': 199, 'young': 200, '1': 201, '10': 202, '12': 203, '13': 204, '14': 205, '15': 206, '16': 207, '17': 208, '18': 209, '19': 210, '2': 211, '21': 212, '22': 213, '24': 214, '25': 215, '3': 216, '4': 217, '5': 218, '6': 219, '9': 220, 'about': 221, 'acts': 222, 'all': 223, 'another': 224, 'apostle': 225, 'apostles': 226, 'apply': 227, 'are': 228, 'away': 229, 'b': 230, 'baptism': 231, 'based': 232, 'because': 233, 'become': 234, 'both': 235, 'c': 236, 'cannot': 237, 'choose': 238, 'churches': 239, 'close': 240, 'come': 241, 'conclusion': 242, 'considered': 243, 'corinthians': 244, 'course': 245, 'daily': 246, 'didn': 247, 'disciples': 248, 'doctrine': 249, 'doctrines': 250, 'duty': 251, 'each': 252, 'encourage': 253, 'entirely': 254, 'especially': 255, 'faithful': 256, 'family': 257, 'find': 258, 'following': 259, 'foundation': 260, 'god': 261, 'group': 262, 'he': 263, 'head': 264, 'hebrews': 265, 'helpful': 266, 'here': 267, 'his': 268, 'how': 269, 'ideas': 270, 'ie': 271, 'involved': 272, 'jesus': 273, 'level': 274, 'light': 275, 'like': 276, 'live': 277, 'lives': 278, 'make': 279, 'many': 280, 'matthew': 281, 'members': 282, 'miss': 283, 'more': 284, 'must': 285, 'natural': 286, 'new': 287, 'notes': 288, 'on': 289, 'one': 290, 'pastor': 291, 'paul': 292, 'people': 293, 'prophet ...

# %%
bow_corpus = [dictionary.doc2bow(text) for text in processed_corpus]
print(bow_corpus[100])
# Out:
# [(0, 1), (9, 2), (13, 2), (18, 2), (31, 1), (42, 2), (80, 2), (85, 1), (89, 3), (93, 4), (94, 1), (109, 2), (111, 1), (116, 1), (123, 1), (148, 1), (152, 1), (162, 1), (163, 1), (164, 2), (166, 1), (185, 1), (196, 1), (199, 1), (232, 1), (269, 2), (289, 1), (291, 1), (325, 2), (358, 1), (443, 1), (458, 1), (590, 2), (594, 1), (605, 2), (622, 1), (638, 1), (640, 1), (685, 1), (696, 1), (805, 2), (824, 1), (918, 1), (1258, 1), (1358, 1), (1528, 1), (1609, 1), (1633, 1), (1652, 1), (1818, 1), (1819, 1)]

# %%
model = models.TfidfModel(bow_corpus)
#model = models.LsiModel(bow_corpus)
#model = models.LdaModel(bow_corpus)

index = similarities.SparseMatrixSimilarity(model[bow_corpus],num_features=len(dictionary))

t = np.random.randint(len(Xtest))
query_document = re.split('\W+',Xtest[t].lower())
query_bow = dictionary.doc2bow(query_document)
sims = index[model[query_bow]]
docNumber = sorted(enumerate(sims), key=lambda x: x[1], reverse=True)[0][0]
print('Predicted:',y_names[ytrain[docNumber]])
print('Ground Truth:',y_names[ytest[t]])
# Out:
# Predicted: alt.atheism
# Ground Truth: alt.atheism
